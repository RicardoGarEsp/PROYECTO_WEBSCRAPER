# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib.request
import requests
import time 
from multiprocessing import Process, Queue, Pool
import threading
import sys
import numpy as np
import re
#from random_user_agent.user_agent import UserAgent
from random_user_agent.params import SoftwareName, OperatingSystem
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from fake_useragent import UserAgent
from selenium.webdriver.chrome.options import Options
import pandasql as ps
from IPython.display import display,HTML
from datetime import date
from datetime import datetime
import matplotlib
import matplotlib.pyplot as plt

# %%
def func_seminuevos(marca):
    path ="/Users/richa/Downloads/chromedriver" # carga del web driver (asignar ruta donde se encuentra el driver)
    driver=webdriver.Chrome(path)
    
    time.sleep(5)
    url="https://www.cars.com/shopping/results/?dealer_id=&keyword="+marca
    driver.get(url) # instruccion de obtener url parametrizada
    time.sleep(10)
    
    productos=driver.find_elements_by_class_name("vehicle-card-main.js-gallery-click-card")
    
    # asignacion de nombres
    lista_nombres=[]
    for i in range(0,len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_class_name("vehicle-card-link.js-gallery-click-link")[0].text)
        except:
            lista_nombres.append(np.nan)
            
            
    # asignacion de precios
    lista_precios=[]
    for i in range(0,len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("primary-price")[0].text)
        except:
            lista_precios.append(np.nan)
    
    # asignacion de mensualidad
    lista_mens=[]
    for i in range(0,len(productos)):
        try:
            lista_mens.append(productos[i].find_elements_by_class_name("estimated-monthly-payments-tooltip.js-tooltip-container")[0].text)
        except:
            lista_mens.append(np.nan)
            
    today= date.today()
    
    df_seminuevos =pd.DataFrame(columns=["MODELO","PRECIO","MENSUALIDAD"])
    df_seminuevos["MODELO"] = lista_nombres
    df_seminuevos["PRECIO"] = lista_precios
    df_seminuevos["MENSUALIDAD"] = lista_mens
    df_seminuevos["SITIO"] = "cars.com"
    df_seminuevos["FECHA"] = str(today)
    
    driver.quit()
    
    return df_seminuevos

def func_usados(marca):
    path ="/Users/anethenlil/Downloads/chromedriver" # carga del web driver (asignar ruta donde se encuentra el driver)
    driver=webdriver.Chrome(path)
    
    time.sleep(5)
    url="https://www.miauto.com.mx/autos/seminuevos?page=1&search="+marca
    driver.get(url) # instruccion de obtener url parametrizada
    time.sleep(10)
    
    productos=driver.find_elements_by_class_name("col-list-3")
    
    # asignacion de nombres
    lista_nombres=[]
    for i in range(0,len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_class_name("car-item__title")[0].text)
        except:
            lista_nombres.append(np.nan)
            
            
    # asignacion de precios
    lista_precios=[]
    for i in range(0,len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("price")[0].text)
        except:
            lista_precios.append(np.nan)
    
    # asignacion de mensualidad
    lista_mens=[]
    for i in range(0,len(productos)):
        try:
            lista_mens.append(productos[i].find_elements_by_class_name("border-left-white")[0].text)
        except:
            lista_mens.append(np.nan)
            
    today= date.today()
    
    df_usados =pd.DataFrame(columns=["MODELO","PRECIO","MENSUALIDAD"])
    df_usados["MODELO"] = lista_nombres
    df_usados["PRECIO"] = lista_precios
    df_usados["MENSUALIDAD"] = lista_mens
    df_usados["SITIO"] = "miauto.com"
    df_usados["FECHA"] = str(today)
    
    driver.quit()
    
    return df_usados

def func_olx(marca):
    path ="/Users/anethenlil/Downloads/chromedriver" # carga del web driver (asignar ruta donde se encuentra el driver)
    driver=webdriver.Chrome(path)
    
    time.sleep(5)
    url="https://www.olxautos.com.mx/autos_c84/q-"+marca
    driver.get(url) # instruccion de obtener url parametrizada
    time.sleep(10)
    
    productos=driver.find_elements_by_class_name("_2n-rb")
    
    # asignacion de nombres
    lista_nombres=[]
    for i in range(0,len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_class_name("iNTWC")[0].text)
        except:
            lista_nombres.append(np.nan)
            
            
    # asignacion de precios
    lista_precios=[]
    for i in range(0,len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("_3Ttwu")[0].text)
        except:
            lista_precios.append(np.nan)
    
    # asignacion de mensualidad
    lista_mens=[]
    for i in range(0,len(productos)):
        try:
            lista_mens.append(productos[i].find_elements_by_class_name("_2JCoI")[0].text)
        except:
            lista_mens.append(np.nan)
            
    today= date.today()
    
    df_olx =pd.DataFrame(columns=["MODELO","PRECIO","MENSUALIDAD"])
    df_olx["MODELO"] = lista_nombres
    df_olx["PRECIO"] = lista_precios
    df_olx["MENSUALIDAD"] = lista_mens
    df_olx["SITIO"] = "olxautos.com"
    df_olx["FECHA"] = str(today)
    
    driver.quit()
    
    return df_olx

# %%
prod1 = func_seminuevos("honda")
time.sleep(10)
prod1.insert(1,"MARCA",'HONDA')
prod1
# Out:
#                                   MODELO  MARCA      PRECIO     MENSUALIDAD  \
# 0                2020 Honda HR-V Touring  HONDA     $29,997  $421 est./mo.*
# 1             2021 Honda Insight Touring  HONDA     $29,830  $418 est./mo.*
# 2   2019 Honda Pilot Touring 8-Passenger  HONDA     $31,044  $435 est./mo.*
# 3   2017 Honda Accord EX w/Honda Sensing  HONDA     $22,990  $322 est./mo.*
# 4               2013 Honda Pilot Touring  HONDA     $17,833  $250 est./mo.*
# 5               2019 Honda Odyssey Elite  HONDA     $38,397  $539 est./mo.*
# 6                      2020 Honda Fit EX  HONDA     $22,352  $314 est./mo.*
# 7                      2020 Honda Fit EX  HONDA     $21,323  $299 est./mo.*
# 8                 2022 Honda Civic Sport  HONDA     $27,513  $386 est./mo.*
# 9                 2022 Honda Civic Sport  HONDA     $26,794  $376 est./mo.*
# 10                   2020 Honda Civic LX  HONDA     $22,545  $316 est./mo.*
# 11                2021 Honda Civic Sport  HONDA  Not Priced
# 12                    2021 Honda HR-V EX  HONDA  Not Priced
# 13                    2021 Honda HR-V EX  HONDA     $26,997  $379 est./mo.*
# 14                    2021 Honda HR-V EX  HONDA  Not Priced
# 15                    2022 Honda HR-V EX  HONDA     $26,504  $372 est./mo.*
# 16                    2022 Honda HR-V EX  HONDA     $28,606  $401 est./mo.*
# 17                    2022 Honda HR-V EX  HONDA     $27,997  $393 est./mo.*
# 18               2021 Honda Accord Sport  HONDA     $27,594  $387 est./mo.*
# 19                   2020 Honda Civic Si  HONDA     $26,888  $377 est./mo.*
# %%
prod3 = func_seminuevos("ford")
time.sleep(10)
prod3.insert(1,"MARCA",'FORD')
prod3
# Out:
#                               MODELO MARCA    PRECIO       MENSUALIDAD  \
# 0   2023 Ford F-150 Lightning LARIAT  FORD   $87,594  $1,229 est./mo.*
# 1               2022 Ford Escape SEL  FORD   $41,625    $584 est./mo.*
# 2               2022 Ford Escape SEL  FORD   $39,905    $560 est./mo.*
# 3               2022 Ford Escape SEL  FORD   $38,974    $547 est./mo.*
# 4             2022 Ford F-150 Tremor  FORD   $77,290  $1,084 est./mo.*
# 5   2022 Ford F-150 Lightning LARIAT  FORD   $89,950  $1,262 est./mo.*
# 6                2020 Ford Escape SE  FORD   $23,977    $336 est./mo.*
# 7                2020 Ford Escape SE  FORD   $26,577    $373 est./mo.*
# 8             2022 Ford F-150 Raptor  FORD  $104,490  $1,466 est./mo.*
# 9                2020 Ford Escape SE  FORD   $26,577    $373 est./mo.*
# 10         2022 Ford Maverick Lariat  FORD   $42,450    $595 est./mo.*
# 11            2022 Ford F-150 Raptor  FORD  $100,220  $1,406 est./mo.*
# 12            2022 Ford F-150 Lariat  FORD   $73,300  $1,028 est./mo.*
# 13               2020 Ford Escape SE  FORD   $26,977    $378 est./mo.*
# 14            2022 Ford F-150 Lariat  FORD   $68,920    $967 est./mo.*
# 15         2022 Ford Maverick Lariat  FORD   $46,855    $657 est./mo.*
# 16         2023 Ford Bronco Badlands  FORD   $82,080  $1,151 est./mo.*
# 17              2022 Ford Escape SEL  FORD   $41,525    $582 est./mo.*
# 18   2021 Ford Bronco Sport Big Bend  FORD   $29,695    $417 est./mo.*
# 19              2022 Ford Escape SEL  FORD   $40,725    $571 est./mo.*
#
#        SITIO       FECHA
# 0   cars.com  2022-12-15
# 1   cars.com  2022-12-15
# 2   cars.com  2022-12-15
# 3   cars.com  2022-12-15
# 4   cars.com  2022-12-15
# 5   cars.com  2022-12-15
# 6   cars.com  2022-12-15
# 7   cars.com  2022-12-15
# 8   cars.com  2022-12-15
# 9   cars.com  2022-12-15
# 10  cars.com  2022-12-15
# 11  cars.com  2022-12-15
# 12  cars.com  2022-12-15
# 13  cars.com  2022-12-15
# 14  cars.com  2022-12-15
# 15  cars.com  2022-12-15
# 16  cars.com  2022-12-15
# 17  cars.com  2022-12-15
# 18  cars.com  2022-12-15
# 19  cars.com  2022-12-15

# %%
df_seminuevos_final = pd.concat([prod1,prod2,prod3])
df_seminuevos_final = df_seminuevos_final[df_seminuevos_final.MENSUALIDAD!=""]

# %%
df_seminuevos_final.PRECIO = df_seminuevos_final.PRECIO.str.replace(",","")
df_seminuevos_final.PRECIO = df_seminuevos_final.PRECIO.str.replace("$","")
df_seminuevos_final.PRECIO = df_seminuevos_final.PRECIO.str.replace(".","")
# Out:
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/846054654.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_seminuevos_final.PRECIO = df_seminuevos_final.PRECIO.str.replace("$","")
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/846054654.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_seminuevos_final.PRECIO = df_seminuevos_final.PRECIO.str.replace(".","")

# %%
df_seminuevos_final.PRECIO = df_seminuevos_final.PRECIO.astype(float) # cast de datos
df_seminuevos_final.PRECIO = df_seminuevos_final.PRECIO*(19.53) #convertir de usd a mxn

# %%
df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace("/","")
df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace("mo","")
df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace("est","")
df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace("*","")
df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace(",","")
df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace("$","")
df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace(".","")
# Out:
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/1914733023.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace("*","")
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/1914733023.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace("$","")
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/1914733023.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.str.replace(".","")

# %%
df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD.astype(float) # cast de datos
df_seminuevos_final.MENSUALIDAD = df_seminuevos_final.MENSUALIDAD*(19.53) #convertir de usd a mxn

# %%
df_seminuevos_final
# Out:
#                                   MODELO   MARCA      PRECIO  MENSUALIDAD  \
# 0                2020 Honda HR-V Touring   HONDA   585841.41      8222.13
# 1             2021 Honda Insight Touring   HONDA   582579.90      8163.54
# 2   2019 Honda Pilot Touring 8-Passenger   HONDA   606289.32      8495.55
# 3   2017 Honda Accord EX w/Honda Sensing   HONDA   448994.70      6288.66
# 4               2013 Honda Pilot Touring   HONDA   348278.49      4882.50
# 5               2019 Honda Odyssey Elite   HONDA   749893.41     10526.67
# 6                      2020 Honda Fit EX   HONDA   436534.56      6132.42
# 7                      2020 Honda Fit EX   HONDA   416438.19      5839.47
# 8                 2022 Honda Civic Sport   HONDA   537328.89      7538.58
# 9                 2022 Honda Civic Sport   HONDA   523286.82      7343.28
# 10                   2020 Honda Civic LX   HONDA   440303.85      6171.48
# 13                    2021 Honda HR-V EX   HONDA   527251.41      7401.87
# 15                    2022 Honda HR-V EX   HONDA   517623.12      7265.16
# 16                    2022 Honda HR-V EX   HONDA   558675.18      7831.53
# 17                    2022 Honda HR-V EX   HONDA   546781.41      7675.29
# 18               2021 Honda Accord Sport   HONDA   538910.82      7558.11
# 19                   2020 Honda Civic Si   HONDA   525122.64      7362.81
# 0                   2013 Nissan Rogue SL  NISSAN   192546.27      2695.14
# 6      NaN  NISSAN  $219,000      $4,870  miauto.com  2022-12-15
# 7      NaN  NISSAN  $568,000     $12,632  miauto.com  2022-12-15
# 8      NaN  NISSAN  $549,000     $12,209  miauto.com  2022-12-15
# 9      NaN  NISSAN  $265,000      $5,893  miauto.com  2022-12-15
# 10     NaN  NISSAN  $349,000      $7,762  miauto.com  2022-12-15
# 11     NaN  NISSAN  $311,000      $5,187  miauto.com  2022-12-15

# %%
prod6 = func_usados("ford")
time.sleep(10)
prod6.insert(1,"MARCA",'FORD')
prod6
##EN ESTE SITIO NO CONTENIA LOS MODELOS DE LOS AUTOS
# Out:
#     MODELO MARCA    PRECIO MENSUALIDAD       SITIO       FECHA
# 0      NaN  FORD  $349,000      $7,762  miauto.com  2022-12-15
# 1      NaN  FORD  $491,000      $8,190  miauto.com  2022-12-15
# 2      NaN  FORD  $490,000      $8,173  miauto.com  2022-12-15
# 3      NaN  FORD  $305,000      $6,023  miauto.com  2022-12-15
# 4      NaN  FORD  $255,000      $5,671  miauto.com  2022-12-15
# 5      NaN  FORD  $999,990     $22,239  miauto.com  2022-12-15
# 6      NaN  FORD  $589,000     $13,099  miauto.com  2022-12-15
# 7      NaN  FORD  $480,000     $10,675  miauto.com  2022-12-15
# 8      NaN  FORD  $480,000     $10,675  miauto.com  2022-12-15
# 9      NaN  FORD  $498,000     $11,075  miauto.com  2022-12-15
# 10     NaN  FORD  $519,000     $11,542  miauto.com  2022-12-15
# 11     NaN  FORD  $560,000     $12,454  miauto.com  2022-12-15

# %%
df_usados_final = pd.concat([prod4,prod5,prod6])
df_usados_final = df_usados_final[df_usados_final.MODELO!=""]

# %%
df_usados_final.PRECIO = df_usados_final.PRECIO.str.replace(",","")
df_usados_final.PRECIO = df_usados_final.PRECIO.str.replace("$","")
df_usados_final.PRECIO = df_usados_final.PRECIO.str.replace(".","")
df_usados_final.MENSUALIDAD = df_usados_final.MENSUALIDAD.str.replace(",","")
df_usados_final.MENSUALIDAD = df_usados_final.MENSUALIDAD.str.replace("$","")
df_usados_final.MENSUALIDAD = df_usados_final.MENSUALIDAD.str.replace(".","")
# Out:
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/1258688353.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_usados_final.PRECIO = df_usados_final.PRECIO.str.replace("$","")
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/1258688353.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_usados_final.PRECIO = df_usados_final.PRECIO.str.replace(".","")
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/1258688353.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_usados_final.MENSUALIDAD = df_usados_final.MENSUALIDAD.str.replace("$","")
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/1258688353.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_usados_final.MENSUALIDAD = df_usados_final.MENSUALIDAD.str.replace(".","")

# %%
df_usados_final.PRECIO = df_usados_final.PRECIO.astype(float) # cast de datos
df_usados_final.MENSUALIDAD = df_usados_final.MENSUALIDAD.astype(float) # cast de datos

# %%
df_usados_final
# Out:
#     MODELO   MARCA    PRECIO  MENSUALIDAD       SITIO       FECHA
# 0      NaN   HONDA  369000.0       8206.0  miauto.com  2022-12-15
# 1      NaN   HONDA  569000.0          NaN  miauto.com  2022-12-15
# 2      NaN   HONDA  515000.0      11453.0  miauto.com  2022-12-15
# 3      NaN   HONDA  429900.0       9561.0  miauto.com  2022-12-15
# 4      NaN   HONDA  369000.0       7287.0  miauto.com  2022-12-15
# 5      NaN   HONDA  325000.0       7228.0  miauto.com  2022-12-15
# 6      NaN   HONDA  290000.0      10417.0  miauto.com  2022-12-15
# 7      NaN   HONDA  339990.0       7561.0  miauto.com  2022-12-15
# 8      NaN   HONDA  332000.0       5538.0  miauto.com  2022-12-15
# 9      NaN   HONDA  320000.0       6319.0  miauto.com  2022-12-15
# 10     NaN   HONDA  263000.0       5849.0  miauto.com  2022-12-15
# 11     NaN   HONDA  289000.0       5707.0  miauto.com  2022-12-15
# 0      NaN  NISSAN  340000.0       5671.0  miauto.com  2022-12-15
# 1      NaN  NISSAN  309900.0       6120.0  miauto.com  2022-12-15
# 2      NaN  NISSAN  439000.0       9763.0  miauto.com  2022-12-15
# 3      NaN  NISSAN  349900.0       7782.0  miauto.com  2022-12-15
# 4      NaN  NISSAN  365000.0       8117.0  miauto.com  2022-12-15
# 5      NaN  NISSAN  199990.0       3949.0  miauto.com  2022-12-15
# 6      NaN  NISSAN  219000.0       4870.0  miauto.com  2022-12-15
# 7      NaN  NISSAN  568000.0      12632.0  miauto.com  2022-12-15
# 8      NaN  NISSAN  549000.0      12209.0  miauto.com  2022-12-15
# 9      NaN  NISSAN  265000.0       5893.0  miauto.com  2022-12-15
# 10     NaN  NISSAN  349000.0       7762.0  miauto.com  2022-12-15
# 11     NaN  NISSAN  311000.0       5187.0  miauto.com  2022-12-15
# 0      NaN    FORD  349000.0       7762.0  miauto.com  2022-12-15
# 1      NaN    FORD  491000.0       8190.0  miauto.com  2022-12-15
# 2      NaN    FORD  490000.0       8173.0  miauto.com  2022-12-15
# 3      NaN    FORD  305000.0       6023.0  miauto.com  2022-12-15
# 4      NaN    FORD  255000.0       5671.0  miauto.com  2022-12-15
# 5      NaN    FORD  999990.0      22239.0  miauto.com  2022-12-15
# 6      NaN    FORD  589000.0      13099.0  miauto.com  2022-12-15
# 7      NaN    FORD  480000.0      10675.0  miauto.com  2022-12-15
# 8      NaN    FORD  480000.0      10675.0  miauto.com  2022-12-15
# 9      NaN    FORD  498000.0      11075.0  miauto.com  2022-12-15
# 10     NaN    FORD  519000.0      11542.0  miauto.com  2022-12-15
# 11     NaN    FORD  560000.0      12454.0  miauto.com  2022-12-15

# %%
prod7 = func_olx("honda")
time.sleep(10)
prod7.insert(1,"MARCA",'HONDA')
prod7
# Out:
#                  MODELO  MARCA     PRECIO           MENSUALIDAD         SITIO  \
# 0       2017, Honda Fit  HONDA  $ 254,000   Mensualidad $ 4,941  olxautos.com
# 1   2022, Honda Insight  HONDA  $ 592,000  Mensualidad $ 11,517  olxautos.com
# 2     2018, Honda Pilot  HONDA  $ 573,000  Mensualidad $ 11,147  olxautos.com
# 38  Mensualidad $ 4,319  olxautos.com  2022-12-15
# 39  Mensualidad $ 4,105  olxautos.com  2022-12-15

# %%
prod9 = func_olx("ford")
time.sleep(10)
prod9.insert(1,"MARCA",'FORD')
prod9
# Out:
#                     MODELO MARCA     PRECIO           MENSUALIDAD  \
# 0        2018, Ford Escape  FORD  $ 362,000   Mensualidad $ 7,043
# 1          2020, Ford Figo  FORD  $ 232,000   Mensualidad $ 4,513
# 2          2019, Ford Edge  FORD  $ 573,000  Mensualidad $ 11,147
# 3          2019, Ford Edge  FORD  $ 573,000  Mensualidad $ 11,147
# 4          2020, KIA Forte  FORD  $ 359,000   Mensualidad $ 6,984
# 5          2020, KIA Forte  FORD  $ 407,000   Mensualidad $ 7,918
# 6          2017, Ford Figo  FORD  $ 181,000   Mensualidad $ 3,521
# 7          2017, KIA Forte  FORD  $ 263,000   Mensualidad $ 5,117
# 8          2019, KIA Forte  FORD  $ 380,000   Mensualidad $ 7,393
# 9        2018, Ford Escape  FORD  $ 317,573   Mensualidad $ 6,178
# 10       2016, Ford Escape  FORD  $ 315,000   Mensualidad $ 6,128
# 11         2017, KIA Forte  FORD  $ 265,000   Mensualidad $ 5,155
# 12       2018, Ford Escape  FORD  $ 398,000   Mensualidad $ 7,743
# 13       2019, Ford Fusion  FORD  $ 533,000  Mensualidad $ 10,369
# 14       2018, Ford Escape  FORD  $ 335,000   Mensualidad $ 6,517
# 15         2019, Ford Figo  FORD  $ 207,000   Mensualidad $ 4,027
# 16         2018, KIA Forte  FORD  $ 253,000   Mensualidad $ 4,922
# 17         2017, Ford Figo  FORD  $ 193,000   Mensualidad $ 3,755
# 18         2020, Ford Figo  FORD  $ 253,000   Mensualidad $ 4,922
# 19       2018, Ford Escape  FORD  $ 327,000   Mensualidad $ 6,362
# 20         2020, KIA Forte  FORD  $ 312,000   Mensualidad $ 6,070
# 21       2021, Ford Escape  FORD  $ 665,000  Mensualidad $ 12,937
# 22       2017, Ford Fusion  FORD  $ 354,000   Mensualidad $ 6,887
# 23       2017, Ford Escape  FORD  $ 356,000   Mensualidad $ 6,926
# 24       2018, Ford Escape  FORD  $ 354,000   Mensualidad $ 6,887
# 25       2017, Ford Escape  FORD  $ 290,000   Mensualidad $ 5,642
# 26         2017, KIA Forte  FORD  $ 243,000   Mensualidad $ 4,727
# 27       2018, Ford Escape  FORD  $ 423,000   Mensualidad $ 8,229
# 28     2021, Ford EcoSport  FORD  $ 455,000   Mensualidad $ 8,852
# 29     2019, Ford EcoSport  FORD  $ 330,000   Mensualidad $ 6,420
# 30         2017, Ford Figo  FORD  $ 173,000   Mensualidad $ 3,366
# 31       2016, Ford Fusion  FORD  $ 283,000   Mensualidad $ 5,506
# 32         2018, KIA Forte  FORD  $ 264,000   Mensualidad $ 5,136
# 33     2018, Ford EcoSport  FORD  $ 340,000   Mensualidad $ 6,615
# 34     2018, Ford EcoSport  FORD  $ 316,000   Mensualidad $ 6,148
# 35         2019, KIA Forte  FORD  $ 323,000   Mensualidad $ 6,284
# 36     2017, Ford EcoSport  FORD  $ 275,000   Mensualidad $ 5,350
# 37     2020, Ford EcoSport  FORD  $ 380,000   Mensualidad $ 7,393
# 38  2021, Ford ford-bronco  FORD  $ 740,000  Mensualidad $ 14,396
# 39         2020, KIA Forte  FORD  $ 323,000   Mensualidad $ 6,284
#
#            SITIO       FECHA
# 0   olxautos.com  2022-12-15
# 1   olxautos.com  2022-12-15
# 2   olxautos.com  2022-12-15
# 3   olxautos.com  2022-12-15
# 4   olxautos.com  2022-12-15
# 5   olxautos.com  2022-12-15
# 6   olxautos.com  2022-12-15
# 7   olxautos.com  2022-12-15
# 8   olxautos.com  2022-12-15
# 9   olxautos.com  2022-12-15
# 10  olxautos.com  2022-12-15
# 11  olxautos.com  2022-12-15
# 12  olxautos.com  2022-12-15
# 13  olxautos.com  2022-12-15
# 14  olxautos.com  2022-12-15
# 15  olxautos.com  2022-12-15
# 16  olxautos.com  2022-12-15
# 17  olxautos.com  2022-12-15
# 18  olxautos.com  2022-12-15
# 19  olxautos.com  2022-12-15
# 20  olxautos.com  2022-12-15
# 21  olxautos.com  2022-12-15
# 22  olxautos.com  2022-12-15
# 23  olxautos.com  2022-12-15
# 24  olxautos.com  2022-12-15
# 25  olxautos.com  2022-12-15
# 26  olxautos.com  2022-12-15
# 27  olxautos.com  2022-12-15
# 28  olxautos.com  2022-12-15
# 29  olxautos.com  2022-12-15
# 30  olxautos.com  2022-12-15
# 31  olxautos.com  2022-12-15
# 32  olxautos.com  2022-12-15
# 33  olxautos.com  2022-12-15
# 34  olxautos.com  2022-12-15
# 35  olxautos.com  2022-12-15
# 36  olxautos.com  2022-12-15
# 37  olxautos.com  2022-12-15
# 38  olxautos.com  2022-12-15
# 39  olxautos.com  2022-12-15

# %%
df_olx_final = pd.concat([prod7,prod8,prod9])
df_olx_final = df_olx_final[df_olx_final.MODELO!=""]

# %%
df_olx_final.PRECIO = df_olx_final.PRECIO.str.replace(",","")
df_olx_final.PRECIO = df_olx_final.PRECIO.str.replace("$","")
df_olx_final.PRECIO = df_olx_final.PRECIO.str.replace(".","")
df_olx_final.MENSUALIDAD = df_olx_final.MENSUALIDAD.str.replace(",","")
df_olx_final.MENSUALIDAD = df_olx_final.MENSUALIDAD.str.replace("$","")
df_olx_final.MENSUALIDAD = df_olx_final.MENSUALIDAD.str.replace(".","")
df_olx_final.MENSUALIDAD = df_olx_final.MENSUALIDAD.str.replace("Mensualidad","")
# Out:
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/554184922.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_olx_final.PRECIO = df_olx_final.PRECIO.str.replace("$","")
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/554184922.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_olx_final.PRECIO = df_olx_final.PRECIO.str.replace(".","")
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/554184922.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_olx_final.MENSUALIDAD = df_olx_final.MENSUALIDAD.str.replace("$","")
# /var/folders/hy/jvcdclh95hg5vt1tl7tyx31m0000gn/T/ipykernel_42834/554184922.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_olx_final.MENSUALIDAD = df_olx_final.MENSUALIDAD.str.replace(".","")

# %%
df_olx_final.PRECIO = df_olx_final.PRECIO.astype(float) # cast de datos
df_olx_final.MENSUALIDAD = df_olx_final.MENSUALIDAD.astype(float) # cast de datos

# %%
df_olx_final
# Out:
#                     MODELO  MARCA    PRECIO  MENSUALIDAD         SITIO  \
# 0          2017, Honda Fit  HONDA  254000.0       4941.0  olxautos.com
# 1      2022, Honda Insight  HONDA  592000.0      11517.0  olxautos.com
# 2        2018, Honda Pilot  HONDA  573000.0      11147.0  olxautos.com
# 3         2017, Honda City  HONDA  231000.0       4494.0  olxautos.com
# 4        2017, Honda Civic  HONDA  294000.0       5720.0  olxautos.com
# ..                     ...    ...       ...          ...           ...
# 35         2019, KIA Forte   FORD  323000.0       6284.0  olxautos.com
# 36     2017, Ford EcoSport   FORD  275000.0       5350.0  olxautos.com
# 37     2020, Ford EcoSport   FORD  380000.0       7393.0  olxautos.com
# 38  2021, Ford ford-bronco   FORD  740000.0      14396.0  olxautos.com
# 39         2020, KIA Forte   FORD  323000.0       6284.0  olxautos.com
#
#          FECHA
# 0   2022-12-15
# 1   2022-12-15
# 2   2022-12-15
# 3   2022-12-15
# 4   2022-12-15
# ..         ...
# 35  2022-12-15
# 36  2022-12-15
# 37  2022-12-15
# 38  2022-12-15
# 39  2022-12-15
#
# [120 rows x 6 columns]

# %%
df_tabla_final = pd.concat([df_seminuevos_final,df_usados_final,df_olx_final])

# %%
df_tabla_final
# Out:
#                                   MODELO  MARCA     PRECIO  MENSUALIDAD  \
# 0                2020 Honda HR-V Touring  HONDA  585841.41      8222.13
# 1             2021 Honda Insight Touring  HONDA  582579.90      8163.54
# 2   2019 Honda Pilot Touring 8-Passenger  HONDA  606289.32      8495.55
# 3   2017 Honda Accord EX w/Honda Sensing  HONDA  448994.70      6288.66
# 4               2013 Honda Pilot Touring  HONDA  348278.49      4882.50
# ..                                   ...    ...        ...          ...
# 35                       2019, KIA Forte   FORD  323000.00      6284.00
# 36                   2017, Ford EcoSport   FORD  275000.00      5350.00
# 37                   2020, Ford EcoSport   FORD  380000.00      7393.00
# 38                2021, Ford ford-bronco   FORD  740000.00     14396.00
# 39                       2020, KIA Forte   FORD  323000.00      6284.00
#
#            SITIO       FECHA
# 0       cars.com  2022-12-15
# 1       cars.com  2022-12-15
# 2       cars.com  2022-12-15
# 3       cars.com  2022-12-15
# 4       cars.com  2022-12-15
# ..           ...         ...
# 35  olxautos.com  2022-12-15
# 36  olxautos.com  2022-12-15
# 37  olxautos.com  2022-12-15
# 38  olxautos.com  2022-12-15
# 39  olxautos.com  2022-12-15
#
# [212 rows x 6 columns]

# %%
plt.bar(df_tabla_final['MARCA'],df_tabla_final['MENSUALIDAD']) #gráfica que muestra la tendencia de las mensualidades
plt.title('MARCA - MENSUALIDAD')
plt.show()

# %%
# Creamos el excel
df_tabla_final.to_excel("df_tabla_final.xlsx",index=False)

# %%
# Hacemos algunas consultas simples de SQL

# %%
ps.sqldf("SELECT (MARCA) FROM df_olx_final") #1
# Out:
#      MARCA
# 0    HONDA
# 1    HONDA
# 2    HONDA
# 3    HONDA
# 4    HONDA
# ..     ...
# 115   FORD
# 116   FORD
# 117   FORD
# 118   FORD
# 119   FORD
#
# [120 rows x 1 columns]

# %%
ps.sqldf("SELECT * FROM df_olx_final where PRECIO>500000") #2
# Out:
#                     MODELO   MARCA    PRECIO  MENSUALIDAD         SITIO  \
# 0      2022, Honda Insight   HONDA  592000.0      11517.0  olxautos.com
# 1        2018, Honda Pilot   HONDA  573000.0      11147.0  olxautos.com
# 2      2018, Honda Odyssey   HONDA  708000.0      13774.0  olxautos.com
# 3      2019, Honda Insight   HONDA  534000.0      10389.0  olxautos.com
# 4         2019, Honda CR-V   HONDA  518000.0      10077.0  olxautos.com
# 5         2019, Honda CR-V   HONDA  518000.0      10077.0  olxautos.com
# 6         2019, Honda CR-V   HONDA  533000.0      10369.0  olxautos.com
# 7     2019, Nissan X-Trail  NISSAN  513530.0       9990.0  olxautos.com
# 8          2019, Ford Edge    FORD  573000.0      11147.0  olxautos.com
# 9          2019, Ford Edge    FORD  573000.0      11147.0  olxautos.com
# 10       2019, Ford Fusion    FORD  533000.0      10369.0  olxautos.com
# 11       2021, Ford Escape    FORD  665000.0      12937.0  olxautos.com
# 12  2021, Ford ford-bronco    FORD  740000.0      14396.0  olxautos.com
#
#          FECHA
# 0   2022-12-15
# 1   2022-12-15
# 2   2022-12-15
# 3   2022-12-15
# 4   2022-12-15
# 5   2022-12-15
# 6   2022-12-15
# 7   2022-12-15
# 8   2022-12-15
# 9   2022-12-15
# 10  2022-12-15
# 11  2022-12-15
# 12  2022-12-15

# %%
ps.sqldf("SELECT (MODELO),(PRECIO) FROM df_tabla_final where PRECIO between 300000 and 500000") #3
# Out:
#                                   MODELO     PRECIO
# 0   2017 Honda Accord EX w/Honda Sensing  448994.70
# 1               2013 Honda Pilot Touring  348278.49
# 2                      2020 Honda Fit EX  436534.56
# 3                      2020 Honda Fit EX  416438.19
# 4                    2020 Honda Civic LX  440303.85
# ..                                   ...        ...
# 94                   2018, Ford EcoSport  340000.00
# 95                   2018, Ford EcoSport  316000.00
# 96                       2019, KIA Forte  323000.00
# 97                   2020, Ford EcoSport  380000.00
# 98                       2020, KIA Forte  323000.00
#
# [99 rows x 2 columns]

# %%
ps.sqldf("SELECT (MODELO),(PRECIO) FROM df_tabla_final where MARCA ='HONDA'") #4
# Out:
#                                   MODELO     PRECIO
# 0                2020 Honda HR-V Touring  585841.41
# 1             2021 Honda Insight Touring  582579.90
# 2   2019 Honda Pilot Touring 8-Passenger  606289.32
# 3   2017 Honda Accord EX w/Honda Sensing  448994.70
# 4               2013 Honda Pilot Touring  348278.49
# ..                                   ...        ...
# 64                       2019, Honda Fit  260000.00
# 65                      2018, Honda CR-V  491000.00
# 66                       2019, Honda Fit  292000.00
# 67                      2016, Honda CR-V  365000.00
# 68                      2019, Honda CR-V  533000.00
#
# [69 rows x 2 columns]

# %%
ps.sqldf("SELECT count(MODELO) FROM df_tabla_final where MARCA='FORD'") #5
# Out:
#    count(MODELO)
# 0             60

# %%
ps.sqldf("SELECT (MARCA) FROM df_tabla_final where SITIO!='cars.com'") #6
# Out:
#      MARCA
# 0    HONDA
# 1    HONDA
# 2    HONDA
# 3    HONDA
# 4    HONDA
# ..     ...
# 151   FORD
# 152   FORD
# 153   FORD
# 154   FORD
# 155   FORD
#
# [156 rows x 1 columns]

# %%
ps.sqldf("SELECT (MARCA),(PRECIO) FROM df_usados_final where MARCA!='FORD' and  PRECIO not between 300000 and 500000") #7
# Out:
#     MARCA    PRECIO
# 0   HONDA  569000.0
# 1   HONDA  515000.0
# 2   HONDA  290000.0
# 3   HONDA  263000.0
# 4   HONDA  289000.0
# 5  NISSAN  199990.0
# 6  NISSAN  219000.0
# 7  NISSAN  568000.0
# 8  NISSAN  549000.0
# 9  NISSAN  265000.0

# %%
ps.sqldf("SELECT (MARCA),(MENSUALIDAD),(SITIO) FROM df_seminuevos_final where MENSUALIDAD>8000") #8
# Out:
#      MARCA  MENSUALIDAD     SITIO
# 0    HONDA      8222.13  cars.com
# 1    HONDA      8163.54  cars.com
# 2    HONDA      8495.55  cars.com
# 3    HONDA     10526.67  cars.com
# 4   NISSAN     10721.97  cars.com
# 5   NISSAN     12342.96  cars.com
# 6   NISSAN     10585.26  cars.com
# 7   NISSAN     10585.26  cars.com
# 8   NISSAN     15018.57  cars.com
# 9   NISSAN     10585.26  cars.com
# 10  NISSAN     10702.44  cars.com
# 11  NISSAN     10585.26  cars.com
# 12  NISSAN     10585.26  cars.com
# 13  NISSAN     10585.26  cars.com
# 14    FORD     24002.37  cars.com
# 15    FORD     11405.52  cars.com
# 16    FORD     10936.80  cars.com
# 17    FORD     10682.91  cars.com
# 18    FORD     21170.52  cars.com
# 19    FORD     24646.86  cars.com
# 20    FORD     28630.98  cars.com
# 21    FORD     11620.35  cars.com
# 22    FORD     27459.18  cars.com
# 23    FORD     20076.84  cars.com
# 24    FORD     18885.51  cars.com
# 25    FORD     12831.21  cars.com
# 26    FORD     22479.03  cars.com
# 27    FORD     11366.46  cars.com
# 28    FORD      8144.01  cars.com
# 29    FORD     11151.63  cars.com

# %%
ps.sqldf("SELECT count(MODELO) FROM df_tabla_final where SITIO!='olxautos.com'") #9
# Out:
#    count(MODELO)
# 0             56

# %%
ps.sqldf("SELECT (MODELO),(MENSUALIDAD) FROM df_tabla_final where SITIO!='miauto.com'") #10
# Out:
#                                    MODELO  MENSUALIDAD
# 0                 2020 Honda HR-V Touring      8222.13
# 1              2021 Honda Insight Touring      8163.54
# 2    2019 Honda Pilot Touring 8-Passenger      8495.55
# 3    2017 Honda Accord EX w/Honda Sensing      6288.66
# 4                2013 Honda Pilot Touring      4882.50
# ..                                    ...          ...
# 171                       2019, KIA Forte      6284.00
# 172                   2017, Ford EcoSport      5350.00
# 173                   2020, Ford EcoSport      7393.00
# 174                2021, Ford ford-bronco     14396.00
# 175                       2020, KIA Forte      6284.00
#
# [176 rows x 2 columns]

# %%
ps.sqldf("SELECT count(MARCA) FROM df_tabla_final where SITIO!='miauto.com'") #11
# Out:
#    count(MARCA)
# 0           176
